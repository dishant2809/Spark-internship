# %% [markdown]
# ### Name:- Dishant Deshmukh¶
#
# ## The Sparks Foundation - Data Science & Business Analytics Internship

# %% [markdown]
# ## Task 3 - Exploratory Data Analysis
# ### In this task we are going to visualize SampleSuperstore data .
# #### Steps :
# #### Step 1 - Importing the dataset
# #### Step 2 - Check for missing data
# #### Step 3 - Dealing with missing data(if any)
# #### Step 4 - Visualize it

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('SampleSuperstore.csv')

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
plt.figure(figsize=(15,10))
sns.barplot(df['State'].value_counts().index,df['State'].value_counts(),palette='rainbow')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(df['Category'].value_counts().index,df['Category'].value_counts())
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(df['Sub-Category'].value_counts(),labels=df['Sub-Category'].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(df['Category'],hue=df['Segment'])
plt.show()

# %%
df.hist(figsize=(10,10),bins=50)
plt.show()

# %%
df.groupby('Category')[['Profit','Sales']].sum().plot.bar(color=['orange','red'],figsize=(8,5))
plt.ylabel('Profit/Loss and Sales')
plt.show()

# %%
sns.lineplot(x='Quantity',y='Profit',label='Profit',data=df)
plt.legend()
plt.show()

# %%
plt.scatter(df['Sales'],df['Profit'])
